# %% [markdown]
# Logs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Changes for log visuals
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
