# %% [markdown]
# adding not wanted comment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# checking status
# ![image.png](attachment:image.png)

# %% [markdown]
# canceling of changes
#
# ![image.png](attachment:image.png)
